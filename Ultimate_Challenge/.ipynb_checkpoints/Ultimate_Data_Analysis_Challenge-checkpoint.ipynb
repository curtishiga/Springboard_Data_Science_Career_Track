# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import math

# %% [markdown]
# # Part 1 - Exploratory Data Analysis
#
# ### Problem:
# From the *logins.json*:
# + Aggregate login counts based on 15-minute time intervals
# + Visualize and describe the resulting time series of login counts in ways that best characterize the uderlying patterns of the demand
# + Please report/illustrate important features of the demand, such as daily cyclces
# + Report data quality issues

# %%
# Import the json file as a pandas DataFrame
with open('logins.json', 'r') as json_file:
    json_data = json.load(json_file)

# Create a dataframe with login_time as the index
logins = pd.DataFrame(index = json_data['login_time'])

# Convert index into datetime objects
logins.index = pd.to_datetime(logins.index)

# %%
logins.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [1970-01-01 20:13:18, 1970-01-01 20:16:10, 1970-01-01 20:16:37, 1970-01-01 20:16:36, 1970-01-01 20:26:21]

# %%
logins.tail()
# Out:
# Empty DataFrame
# Columns: []
# Index: [1970-04-13 18:50:19, 1970-04-13 18:43:56, 1970-04-13 18:54:02, 1970-04-13 18:57:38, 1970-04-13 18:54:23]

# %%
# Determine the number of 15-minute intervals within the dataset timeframe
time_range = logins.login_time[93141] - logins.login_time[0]
print(time_range)
# Out:
# 101 days 22:41:05
# 20417

# %%
_ = plt.figure(figsize=(15,15))
(n, bins, patches) = plt.hist(logins.login_time, bins = num_bins)

# %%
logins['count'] = 1

logins.resample('15T').count()
# Out:
#                      count
# 1970-01-01 20:00:00      2
# 1970-01-01 20:15:00      6
# 1970-01-01 20:30:00      9
# 1970-01-01 20:45:00      7
# 1970-01-01 21:00:00      1
# 1970-01-01 21:15:00      4
# 1970-01-01 21:30:00      0
# 1970-01-01 21:45:00      4
# 1970-01-01 22:00:00      9
# 1970-01-01 22:15:00      8
# 1970-01-01 22:30:00      1
# 1970-01-01 22:45:00      3
# 1970-01-01 23:00:00     16
# 1970-01-01 23:15:00     13
# 1970-01-01 23:30:00     14
# 1970-01-01 23:45:00     15
# 1970-01-02 00:00:00     10
# 1970-01-02 00:15:00     18
# 1970-01-02 00:30:00     12
# 1970-01-02 00:45:00     13
# 1970-01-02 01:00:00      9
# 1970-01-02 01:15:00      8
# 1970-01-02 01:30:00     10
# 1970-01-02 01:45:00      6
# 1970-01-02 02:00:00      7
# 1970-01-02 02:15:00     18
# 1970-01-02 02:30:00     12
# 1970-01-02 02:45:00      6
# 1970-01-02 03:00:00     12
# 1970-01-02 03:15:00      5
# ...                    ...
# 1970-04-13 11:30:00     13
# 1970-04-13 11:45:00      7
# ...
